# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Exercises
# ### Create a file named seaborn_exercises.py or seaborn_exercises.ipynb for this exercise.

# %% [markdown]
# Use seaborn's load_dataset function to load the iris database to answer the following questions:

# %%
iris = sns.load_dataset('iris')

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# #### 1.a What does the distribution of petal lengths look like?

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(x='species', y='petal_length', hue='species', data=iris)

# %% [markdown]
# #### 1.b. Is there a relationship between petal length and petal width?

# %%
sns.relplot(x='petal_width', y='petal_length',hue ='species', data=iris)

# %% [markdown]
# #### 1.c. Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.scatterplot(data= iris, x='sepal_width', y='sepal_length', hue="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# #### 1.d. Which features would be best used to predict species?

# %% [markdown]
# The best way to predict the species would be petal length or petal width

# %%
sns.boxplot(y='petal_width',x="species", hue ='species', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
## Brooke does before or after starting project
sns.pairplot(data= iris, hue='species')

# %% [markdown]
# ### 1.Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')

anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
sns.relplot(data= anscombe, x= 'x', y = "y", col='dataset')

# %% [markdown]
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.barplot(data= anscombe, x='x', y='y',  hue='dataset')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### 2. Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
from pydataset import data

InsectSprays = data("InsectSprays")
print(InsectSprays.dtypes)
# Out:
# count     int64
# spray    object
# dtype: object

# %%
InsectSprays.show_doc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 InsectSprays.show_doc()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show_doc'

# %%
InsectSprays.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
sns.boxplot(data= InsectSprays, x='spray', y='count', hue="spray")
plt.title("Compare the efectiveness of insect spray")
# Out:
# Text(0.5, 1.0, 'Compare the efectiveness of insect spray')

# %% [markdown]
# ### 3. Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:

# %%
from pydataset import data

swiss = data("swiss")
print(swiss.dtypes)
# Out:
# Fertility           float64
# Agriculture         float64
# Examination           int64
# Education             int64
# Catholic            float64
# Infant.Mortality    float64
# dtype: object

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
 swiss.describe()
# Out:
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# max    92.500000    89.700000    37.000000  53.000000  100.00000
#
#        Infant.Mortality
# count         47.000000
# mean          19.942553
# std            2.912697
# min           10.800000
# 25%           18.150000
# 50%           20.000000
# 75%           21.700000
# max           26.600000

# %%
swiss.shape
# Out:
# (47, 6)

# %%
swiss(show , True )

# %% [markdown]
# #### Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss['is_catholic'] = swiss.Catholic >= 50
swiss.head(10)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

swiss_sorted = swiss.sort_values(by='Fertility', ascending=False)
swiss_sorted.head(15)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Franches-Mnt       92.5         39.7            5          5     93.40
# Glane              92.4         67.8           14          8     97.16
# Sierre             92.2         84.6            3          3     99.46
# Veveyse            87.1         64.5           14          6     98.61
# Moutier            85.8         36.5           12          7     33.77
# Broye              83.8         70.2           16          7     92.85
# Delemont           83.1         45.1            6          9     84.84
# Sarine             82.9         45.2           16         13     91.38
# Gruyere            82.4         53.3           12          7     97.67
# Courtelary         80.2         17.0           15         12      9.96
# Monthey            79.4         64.9            7          3     98.22
# Sion               79.3         63.1           13         13     96.83
# ...

# %% [markdown]
# #### Does whether or not a province is Catholic influence fertility?

# %% [markdown]
# YES, whethern a province is Catholic does influence fertility

# %%
sns.boxplot(data= swiss, x='is_catholic', y='Fertility', hue= 'is_catholic')
# Out:
# <Axes: xlabel='is_catholic', ylabel='Fertility'>

# %%
swiss.corr()['Fertility']
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# is_catholic         0.402813
# Name: Fertility, dtype: float64

# %% [markdown]
# #### What measure correlates most strongly with fertility?

# %% [markdown]
# Religion correlates the most with fertility.

# %% [markdown]
# #### 4. Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from pydataset import data
from env import user, password, hostname 
import pymysql as sql
def get_db_url (user, password, hostname, db_name):    
    return (f'mysql+pymysql://{user}:{password}@{hostname}/{db_name}')

# %%
chipotle_url = get_db_url(user, password, hostname, 'chipotle')
sql = 'SELECT * FROM orders'
chipotle_df = pd.read_sql(sql, chipotle_url)
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
chipotle_df.describe()
# Out:
#                 id     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2311.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       1.000000     1.000000     1.000000
# 25%    1156.250000   477.250000     1.000000
# 50%    2311.500000   926.000000     1.000000
# 75%    3466.750000  1393.000000     1.000000
# max    4622.000000  1834.000000    15.000000

# %%
chipotle_df.shape
# Out:
# (4622, 6)

# %%
chipotle_df.

# %%
most_rev = sum('item_price'* 'quanity')

# top_four = chipotle_df.groupby('item_name').quantity.sum().sort_values(ascending = False).head(4)
# top_four

# %% [markdown]
# #### 5. Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
from pydataset import data

sleepstudy = data("sleepstudy")
print(sleepstudy.dtypes)
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
data('sleepstudy', show_doc=True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %%
sleepstudy.describe()
# Out:
#          Reaction        Days     Subject
# count  180.000000  180.000000  180.000000
# mean   298.507892    4.500000  341.277778
# std     56.328757    2.880293   20.320905
# min    194.332200    0.000000  308.000000
# 25%    255.375825    2.000000  331.000000
# 50%    288.650800    4.500000  336.000000
# 75%    336.752075    7.000000  352.000000
# max    466.353500    9.000000  372.000000

# %%
sleepstudy.shape
# Out:
# (180, 3)

# %%
sleepstudy.head(5)
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
sns.lineplot(data= sleepstudy, x='Days', y='Reaction', hue="Subject")
plt.title("SLEEP Study")
# Out:
# Text(0.5, 1.0, 'SLEEP Study')
