# %%
#import pyplot module as alias plt
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Exercises I

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y = x**2 − x + 2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
# Calculate y values based on the equation
x = np.linspace(-10, 10, 100)
y = x**2 - x + 2




# Create the plot
plt.plot(x, y, color= 'pink', ls='--') 

plt.xlabel('x')
plt.ylabel('y')
plt.title('Matplot of y = x^2 - x + 2')
plt.grid(True)

# Add annotation for the point (0, 0)
plt.annotate('(0, 0)', xy=(0, 0), xytext=(3, 30))
             #textcoords='offset points', arrowprops=dict(arrowstyle='->'))

# Show the plot
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# *y =√x
# *y =x**3
# *y = 2x
# *y=1/(x+1)
# You can use functions from the math module to help implement some of the equations above.

# %%
# Range of x values
x = np.linspace(0, 10, 100)

# Plot: y = sqrt(x)
y1 = np.sqrt(x)
plt.figure()
plt.plot(x, y1, color='gray')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = sqrt(x)')
plt.show()

# %%
# Plot: y = x^3
x = np.linspace(0, 10, 100)

y2 = x**3
plt.figure()
plt.plot(x, y2, color='c')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^3')
plt.show()

# %%
# Plot: y = 2x
x = np.linspace(0, 10, 100)
y3 = 2 * x
plt.figure()
plt.plot(x, y3, color='m')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = 2x')
plt.show()

# %%
# Plot: y = 1/(x + 1)
x = np.linspace(0, 10, 100)
y4 = [1 / (val + 1) for val in x]
plt.figure()
plt.plot(x, y4, color='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = 1/(x + 1)')


plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
#Close but NO Revised below
plt.figure()
plt.subplot(2, 2, 1)
x = np.linspace(0, 10, 100)
y1 = np.sqrt(x)
plt.plot(x, y1, color='gray')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = sqrt(x)')

plt.subplot(2, 2, 2)
# Plot: y = x^3
x = np.linspace(0, 10, 100)

y2 = x**3
plt.plot(x, y2, color='c')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^3')

plt.subplot(2, 2, 3)
x = np.linspace(0, 10, 100)
y4 = [1 / (val + 1) for val in x]
plt.plot(x, y4, color='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = 1/(x + 1)')


plt.subplot(2, 2, 4)
x = np.linspace(0, 10, 100)
y3 = 2 * x
plt.plot(x, y3, color='m')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = 2x')
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
# Set up the figure with 2 rows and 2 columns
fig, axs = plt.subplots(2, 2)

# Plot: y = sqrt(x)
x = np.linspace(0, 10, 100)
y1 = np.sqrt(x)
axs[0, 0].plot(x, y1, color='gray', label='plot 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].set_title('Plot of y = sqrt(x)')

# Plot: y = x^3
y2 = x**3
axs[0, 1].plot(x, y2, color='c', label='plot 2')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].set_title('Plot of y = x^3')

# Plot: y = 1/(x + 1)
y4 = 1 / (x + 1)
axs[1, 0].plot(x, y4, color='y', label='plot 3')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].set_title('Plot of y = 1/(x + 1)')

# Plot: y = 2x
y3 = 2 * x
axs[1, 1].plot(x, y3, color='m',label='plot 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].set_title('Plot of y = 2x')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
fig.legend(loc='outside upper right')
plt.suptitle('THE PLOTS')
fig.tight_layout()
plt.show()

# %% [markdown]
# 5.Make a new Jupyter notebook named big_o_notation.ipynb
#
# *Title your chart "Big O Notation"
# *Label your x axis "Elements"
# *Label your y axis "Operations"
# *Label your curves or make a legend for the curves
# *Use LaTex notation where possible
# Curves to graph
#
# y=0n+1 and label the curve "O(1)"
# y=log(n) and label the curve "O(log n)"
# y=n and label the curve "O(n)"
# y=n∗log(n) and label it "O(n log n)"
# y=n**2 and label it "O(n^2)"
# y=2n and label it "O(2^n)"
# y=n! and label it "O(n!)"
# y=n**n and label it "O(n^n)"

# %% [markdown]
# MINI lesson Scatter plot

# %%
#answer import math

x = [x * 0.1 for x in range(-70,70)]
# We can use math.sin(x) to create the y values according to our formula
y = [math.sin(x) for x in x]

plt.scatter(x,y)
plt.axhline(0, ls='--')
plt.text(0,0, 'origin')
# Out:
# Text(0, 0, 'origin')

# %%
x = x = np.arange(-7, 7, 0.1)
y = np.sin(x) 

a = np.random.rand(len(x))
b = np.random.rand(len(x))
size = np.random.randint(10, 100, len(x))
clr = np.random.rand(len(x))

# Create the scatter plot
plt.scatter(a, b, s=size, c=clr, cmap='plasma')
plt.colorbar()

# Set x and y labels
plt.xlabel('x')
plt.ylabel('y')
plt.title('My first scatter plot')
plt.scatter(a,b, s = size, c = clr, cmap = 'plasma')

plt.colorbar()
